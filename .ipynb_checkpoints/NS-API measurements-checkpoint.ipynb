# %% [markdown]
# In this assingment there is done a measure of how many train stations are affected by a disruption with the NS-API. Here we can see what trainstation has the most disruptions. Also we can see the total amount of disruptions for all trainstations. Next, there is a measure of the most disruptions per trainstation. Finally, there is a measure of the trainstation with the most delay.

# %% [markdown]
# Import required packages.

# %%
from api.amsterdam_api import AmsterdamApi
from api.ns_api import NSApi
from collections import Counter

# %% [markdown]
# Function for getting dict keys by duplicated values. This is used to get a list of the most disruptions per trainstation.

# %%
# Get keys by duplicate values
def getKeysByValues(dictOfElements, listOfValues):
    listOfKeys = list()
    listOfItems = dictOfElements.items()
    for item  in listOfItems:
        # If value is duplicated then append key to the list
        if item[1] in listOfValues:
            listOfKeys.append(item[0])
    return  listOfKeys

# %% [markdown]
# Measures how many train stations are affected now by a disruption.

# %%
print("NS API Test")
ns_api = NSApi()

# NSApiGet a list of train stations
# print(ns_api.get_train_stations())

# Get a list of disruptions
# print(ns_api.get_disruptions())

# Extend all stations with disruptions to get 1 array
disruption_list = []
for disruption in ns_api.get_disruptions():
    disruption_list.extend(disruption.get("stations"))
    
counter = 0
for train_stations in ns_api.get_train_stations():
    counter = counter + 1

# Get a dict of counters foreach disruption
c = (Counter(disruption_list))

# Divide the amount of disruptions by the total amount of trainstations
print(str("Percentage of total disruptions is: ") + str((len(c)/counter)*100))
# Out:
# Percentage of total disruptions is: 54.63659147869674

# %% [markdown]
# Get percentage of disruptions per trainstation.

# %%
# Get the station with the most disruptions
key_with_max_value = (max(c, key=c.get))

# Get all the stations with the most disruptions
listOfKeys = getKeysByValues(c, [c[key_with_max_value]])

print("Trainstation, Percentage of disruption")
for key, value in sorted(c.items()):
    print(key, ": ", value/counter)
# Out:
# Trainstation, Percentage of disruption
# ah :  0.015037593984962405
# ahz :  0.007518796992481203
# akl :  0.002506265664160401
# akm :  0.005012531328320802
# amf :  0.002506265664160401
# aml :  0.010025062656641603
# amr :  0.005012531328320802
# amri :  0.005012531328320802
# amrn :  0.002506265664160401
# ana :  0.005012531328320802
# apn :  0.005012531328320802
# ass :  0.002506265664160401
# atw :  0.010025062656641603
# basels :  0.012531328320802004
# bd :  0.010025062656641603
# bde :  0.002506265664160401
# bdg :  0.002506265664160401
# bdpb :  0.002506265664160401
# berch :  0.010025062656641603
# bet :  0.005012531328320802
# bf :  0.005012531328320802
# bh :  0.015037593984962405
# bhdv :  0.002506265664160401
# bk :  0.002506265664160401
# bkf :  0.002506265664160401
# bkg :  0.002506265664160401
# bmr :  0.002506265664160401
# bn :  0.005012531328320802
# bnc :  0.005012531328320802
# bnk :  0.002506265664160401
# bnn :  0.002506265664160401
# bnz :  0.005012531328320802
# bp :  0.002506265664160401
# brd :  0.002506265664160401
# brusz :  0.010025062656641603
# bsd :  0.002506265664160401
# bspd :  0.007518796992481203
# btl :  0.007518796992481203
# cas :  0.002506265664160401
# ck :  0.002506265664160401
# cl :  0.002506265664160401
# da :  0.002506265664160401
# db :  0.002506265664160401
# ddr :  0.005012531328320802
# ddrs :  0.002506265664160401
# op :  0.002506265664160401
# osnh :  0.012531328320802004
# ot :  0.002506265664160401
# otb :  0.002506265664160401
# pmo :  0.002506265664160401
# pmr :  0.002506265664160401
# pmw :  0.002506265664160401
# rd :  0.005012531328320802
# rheine :  0.012531328320802004
# rhn :  0.002506265664160401
# rlb :  0.005012531328320802
# rsn :  0.007518796992481203
# rtb :  0.002506265664160401
# rtd :  0.002506265664160401
# rtst :  0.002506265664160401
# rtz :  0.002506265664160401
# rvs :  0.002506265664160401
# sdt :  0.002506265664160401
# sdtb :  0.002506265664160401
# sgl :  0.002506265664160401
# sgn :  0.002506265664160401
# shl :  0.002506265664160401
# sk :  0.002506265664160401
# sknd :  0.002506265664160401
# sog :  0.002506265664160401
# ssh :  0.002506265664160401
# std :  0.002506265664160401
# stv :  0.002506265664160401
# swd :  0.005012531328320802
# swk :  0.005012531328320802
# tb :  0.005012531328320802
# tbu :  0.002506265664160401
# tl :  0.002506265664160401
# uhm :  0.005012531328320802
# uhz :  0.005012531328320802
# ust :  0.005012531328320802
# ut :  0.002506265664160401
# utg :  0.002506265664160401
# utln :  0.002506265664160401
# utvr :  0.005012531328320802
# vdl :  0.002506265664160401
# vg :  0.002506265664160401
# vh :  0.002506265664160401
# vhp :  0.002506265664160401
# viers :  0.005012531328320802
# vk :  0.002506265664160401
# vndc :  0.002506265664160401
# vndw :  0.002506265664160401
# vz :  0.002506265664160401
# wc :  0.002506265664160401
# wdn :  0.007518796992481203
# wf :  0.002506265664160401
# wfm :  0.005012531328320802
# wk :  0.002506265664160401
# wm :  0.002506265664160401
# wr :  0.002506265664160401
# wsm :  0.005012531328320802
# wv :  0.005012531328320802
# wz :  0.002506265664160401
# za :  0.002506265664160401
# zbm :  0.002506265664160401
# zd :  0.007518796992481203
# zdk :  0.002506265664160401
# zh :  0.002506265664160401
# zl :  0.007518796992481203
# zlsh :  0.002506265664160401
# zv :  0.002506265664160401
# zwd :  0.002506265664160401
# zzs :  0.002506265664160401

# %% [markdown]
# Get a list of the trainstations with the most disruptions.

# %%
print("\nMost common disruptions for trainstations: ")

# Iterate over the list of values
for key in listOfKeys:
    print(key)
# Out:
# Most common disruptions for trainstations:
# ah
# esn
# gwd
# fkth
# gkt
# mid
# lkp
# maria
# lkr
# odz
# bh
# oberh
# duisb

# %%
# Variable for getting the train station with the most delay in seconds
max_sum_seconds = 0

# Loop through all the train stations
for ids in ns_api.get_train_stations():
    id = ids.get('id')
    sum_seconds = 0

    # Loop through all departures for each train station
    for delay_in_seconds in ns_api.get_departures(id):
        seconds = delay_in_seconds.get('delay_seconds')

        # Sum delay seconds for each departure on that trainstation
        if seconds != 0:
            sum_seconds = sum_seconds + seconds

        # Get the train station with the most delay in seconds
        if sum_seconds > max_sum_seconds:
            max_sum_seconds = sum_seconds
            trainstation = ids.get("name")

print(str("\nTrainstation: ") + trainstation + str(" has the most delay with: ") + str(max_sum_seconds) + str(" seconds delay."))
# Out:
# Trainstation: Amsterdam Sloterdijk has the most delay with: 4339 seconds delay.
